# %%
import cv2
import pandas as pd
import numpy as np
import os
import glob
from color_matcher.io_handler import load_img_file
from color_matcher.normalizer import Normalizer
from color_matcher import ColorMatcher
import cv2
import tqdm

# %%
import color_matcher

# %%
source_ls = ['PAL_2020']
target_ls = ['LL', 'HUA', 'PAL_2021', 'RAN', 'TAK']
for source in source_ls:
    for target in target_ls:
        if os.path.exists(source+'synth'+target):
            os.system('rm -r '+source+'synth'+target)
        os.mkdir(source+'synth'+target)
target_img_paths = {}
for target in target_ls:
    target_img_paths[target] = glob.glob(target+'/images/*.JPG', recursive=True)

# %%
CM = ColorMatcher()
for target in target_ls:
    for source in source_ls:
        loc = os.path.join(source, 'images')
        for img_name in tqdm.tqdm(os.listdir(loc)):
            target_img_path = np.random.choice(target_img_paths[target], 1)[0]
            img_ref = load_img_file(target_img_path)
            img_src = load_img_file(loc+'/'+img_name)
            img = CM.transfer(src=img_src, ref=img_ref, method='hm-mvgd-hm')
            img = Normalizer(img).uint8_norm()
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            cv2.imwrite(source+'synth'+target+'/'+img_name, img)
# Out:
#   2%|▏         | 5/248 [00:06<05:30,  1.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3r/4gk3lrps1qbczn0n867c2trc0000gn/T/ipykernel_28302/3139300885.py in <module>
#       7             img_ref = load_img_file(target_img_path)
#       8             img_src = load_img_file(loc+'/'+img_name)
# ----> 9             img = CM.transfer(src=img_src, ref=img_ref, method='hm-mvgd-hm')
#      10             img = Normalizer(img).uint8_norm()
#      11             img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#
# ~/miniforge3/envs/machine-learning/lib/python3.9/site-packages/color_matcher/top_level.py in transfer(self, src, ref, method)
#      94         # proceed with the color match
#      95         for fun in self._funs:
# ---> 96             self._src = fun(self._src, self._ref)
#      97
#      98         return self._src
#
# ...

# %%
# os.mkdir('HUA_MOO_RAI_TTR_TAH2PAL_LL')
# os.mkdir('HUA_MOO_RAI_TTR_TAH2PAL_LL/trainA')
# os.mkdir('HUA_MOO_RAI_TTR_TAH2PAL_LL/trainB')
# os.mkdir('HUA_MOO_RAI_TTR_TAH2PAL_LL/testA')
# os.mkdir('HUA_MOO_RAI_TTR_TAH2PAL_LL/testB')

# %%
# loc_ls = ['HUA', 'MOO', 'RAI', 'TAH', 'TTR']
# trainA = [] # 0.8
# trainB = []
# testA = [] # 0.2
# testB = []
# for loc in tqdm.tqdm(loc_ls):
#     for img_name in os.listdir(loc):
#         r_path = './'+loc+'/'+img_name
#         r_t_path = './transformed_'+loc+'/'+img_name
#         path = './'+img_name
#         if np.random.random(1)[0] > 0.2:
#             # trainA.append(path)
#             # trainB.append(path)
#             os.system('cp '+r_path+' HUA_MOO_RAI_TTR_TAH2PAL_LL/trainA/')
#             os.system('cp '+r_t_path+' HUA_MOO_RAI_TTR_TAH2PAL_LL/trainB/')
#             with open('HUA_MOO_RAI_TTR_TAH2PAL_LL/list_trainA.txt', 'a') as fileA:
#                 fileA.write(path+'\n')
#             with open('HUA_MOO_RAI_TTR_TAH2PAL_LL/list_trainB.txt', 'a') as fileB:
#                 fileB.write(path+'\n')
#         else:
#             # trainA.append(path)
#             # testB.append(path)
#             os.system('cp '+r_path+' HUA_MOO_RAI_TTR_TAH2PAL_LL/testA/')
#             os.system('cp '+r_t_path+' HUA_MOO_RAI_TTR_TAH2PAL_LL/testB/')
#             with open('HUA_MOO_RAI_TTR_TAH2PAL_LL/list_testA.txt', 'a') as fileA:
#                 fileA.write(path+'\n')
#             with open('HUA_MOO_RAI_TTR_TAH2PAL_LL/list_testB.txt', 'a') as fileB:
#                 fileB.write(path+'\n')
